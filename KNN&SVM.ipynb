# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.datasets import load_iris
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Load dataset
iris = load_iris()

df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Mapping target values to species names
species_map = {0: "setosa", 1: "versicolor", 2: "virginica"}
df['target'] = [species_map[i] for i in iris.target]

  # Target labels

# Display first 5 rows
df.head(104)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 99                 5.7               2.8                4.1               1.3
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
#
#          target
# ...

# %%
X =df.iloc[:, [2, 3]].to_numpy()
X
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.7, 0.4],
#        [1.4, 0.3],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.5, 0.1],
#        [1.5, 0.2],
#        [1.6, 0.2],
#        [1.4, 0.1],
#        [1.1, 0.1],
#        [1.2, 0.2],
#        [1.5, 0.4],
#        [1.3, 0.4],
#        [1.4, 0.3],
#        [1.7, 0.3],
#        [1.5, 0.3],
#        [1.7, 0.2],
#        [1.5, 0.4],
#        [1. , 0.2],
#        [1.7, 0.5],
#        [1.9, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.4],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.2],
#        [1.5, 0.4],
#        [1.5, 0.1],
#        [1.4, 0.2],
#        [1.5, 0.2],
#        [1.2, 0.2],
#        [1.3, 0.2],
#        [1.4, 0.1],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.3, 0.3],
#        [1.3, 0.3],
#        [1.3, 0.2],
#        [1.6, 0.6],
#        [1.9, 0.4],
#        [1.4, 0.3],
#        [1.6, 0.2],
# ...

# %%
Y =df.iloc[:,4].to_numpy()
Y
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %%
##split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=7)

# %%
print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 120
# Testing samples: 30

# %%
print(X_test)
# Out:
# [[5.1 1.8]
#  [4.5 1.5]
#  [1.3 0.3]
#  [4.5 1.5]
#  [4.5 1.7]
#  [1.3 0.3]
#  [4.9 1.5]
#  [4.2 1.3]
#  [1.6 0.2]
#  [4.5 1.5]
#  [5.  1.7]
#  [4.5 1.6]
#  [1.5 0.1]
#  [6.1 2.5]
#  [1.4 0.2]
#  [4.8 1.8]
#  [5.8 1.8]
#  [5.5 1.8]
#  [1.6 0.2]
#  [1.4 0.1]
#  [3.9 1.2]
#  [5.7 2.3]
#  [4.7 1.4]
#  [5.  1.5]
#  [5.8 1.6]
#  [4.8 1.8]
#  [4.3 1.3]
#  [3.8 1.1]
#  [5.1 1.9]
#  [5.6 2.4]]

# %%
print(Y_test)
# Out:
# ['virginica' 'versicolor' 'setosa' 'versicolor' 'virginica' 'setosa'
#  'versicolor' 'versicolor' 'setosa' 'versicolor' 'versicolor' 'versicolor'
#  'setosa' 'virginica' 'setosa' 'versicolor' 'virginica' 'virginica'
#  'setosa' 'setosa' 'versicolor' 'virginica' 'versicolor' 'virginica'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'virginica' 'virginica']

# %%
#fit
clf = KNeighborsClassifier()
clf.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
score = clf.score(X_train,Y_train)
score
# Out:
# 0.9833333333333333

# %%
print(clf.predict([[5.6,2.4]]))
# Out:
# ['virginica']

# %%
predict = clf.predict(X_test)
print('oreginal',Y_test)
print('Predict',predict)
# Out:
# oreginal ['virginica' 'versicolor' 'setosa' 'versicolor' 'virginica' 'setosa'
#  'versicolor' 'versicolor' 'setosa' 'versicolor' 'versicolor' 'versicolor'
#  'setosa' 'virginica' 'setosa' 'versicolor' 'virginica' 'virginica'
#  'setosa' 'setosa' 'versicolor' 'virginica' 'versicolor' 'virginica'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'virginica' 'virginica']
# Predict ['virginica' 'versicolor' 'setosa' 'versicolor' 'versicolor' 'setosa'
#  'versicolor' 'versicolor' 'setosa' 'versicolor' 'virginica' 'versicolor'
#  'setosa' 'virginica' 'setosa' 'virginica' 'virginica' 'virginica'
#  'setosa' 'setosa' 'versicolor' 'virginica' 'versicolor' 'versicolor'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'virginica' 'virginica']

# %%
print(classification_report(Y_test,predict)) #precision compare= predict to oreginal, recall compare=oreginal to predict   , support = number of o , 1 ,2
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         7
#   versicolor       0.83      0.83      0.83        12
#    virginica       0.82      0.82      0.82        11
#
#     accuracy                           0.87        30
#    macro avg       0.88      0.88      0.88        30
# weighted avg       0.87      0.87      0.87        30

# %%
df =pd.read_csv(r"C:\Users\ashok\OneDrive\Desktop\Data AI analyst\Py_DS_ML_Bootcamp-master\Refactored_Py_DS_ML_Bootcamp-master\14-K-Nearest-Neighbors\KNN_Project_Data")
df
# Out:
#             XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0    1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1    1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2    1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3    1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4    1018.340526  1313.679056   950.622661  724.742174   843.065903
# ..           ...          ...          ...         ...          ...
# 995  1343.060600  1289.142057   407.307449  567.564764  1000.953905
# 996   938.847057  1142.884331  2096.064295  483.242220   522.755771
# 997   921.994822   607.996901  2065.482529  497.107790   457.430427
# 998  1157.069348   602.749160  1548.809995  646.809528  1335.737820
# 999  1287.150025  1303.600085  2247.287535  664.362479  1132.682562
#
#             HYKR         EDFS        GUUB         MGJM         JHZC  \
# 0    1618.870897  2147.641254  330.727893  1494.878631   845.136088
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df.drop('TARGET CLASS',axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df.drop('TARGET CLASS',axis=1))
print(scaled_features)
# Out:
# [[ 1.56852168 -0.44343461  1.61980773 ... -0.93279392  1.00831307
#   -1.06962723]
#  [-0.11237594 -1.05657361  1.7419175  ... -0.46186435  0.25832069
#   -1.04154625]
#  [ 0.66064691 -0.43698145  0.77579285 ...  1.14929806  2.1847836
#    0.34281129]
#  ...
#  [-0.35889496 -0.97901454  0.83771499 ... -1.51472604 -0.27512225
#    0.86428656]
#  [ 0.27507999 -0.99239881  0.0303711  ... -0.03623294  0.43668516
#   -0.21245586]
#  [ 0.62589594  0.79510909  1.12180047 ... -1.25156478 -0.60352946
#   -0.87985868]]

# %%
df.columns[:-1]
# Out:
# Index(['XVPM', 'GWYH', 'TRAT', 'TLLZ', 'IGGA', 'HYKR', 'EDFS', 'GUUB', 'MGJM',
#        'JHZC'],
#       dtype='object')

# %%
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#        XVPM      GWYH      TRAT      TLLZ      IGGA      HYKR      EDFS  \
# 0  1.568522 -0.443435  1.619808 -0.958255 -1.128481  0.138336  0.980493
# 1 -0.112376 -1.056574  1.741918 -1.504220  0.640009  1.081552 -1.182663
# 2  0.660647 -0.436981  0.775793  0.213394 -0.053171  2.030872 -1.240707
# 3  0.011533  0.191324 -1.433473 -0.100053 -1.507223 -1.753632 -1.183561
# 4 -0.099059  0.820815 -0.904346  1.609015 -0.282065 -0.365099 -1.095644
#
#        GUUB      MGJM      JHZC
# 0 -0.932794  1.008313 -1.069627
# 1 -0.461864  0.258321 -1.041546
# 2  1.149298  2.184784  0.342811
# 3 -0.888557  0.162310 -0.002793
# 4  0.391419 -1.365603  0.787762

# %%
X_train, X_test, Y_train, Y_test = train_test_split(scaled_features,df['TARGET CLASS'],
                                                    test_size=0.30)

# %%
print(X_train)
# Out:
# [[-1.12929746 -0.61552222  0.2080132  ... -0.31673662 -0.0840473
#   -1.38187372]
#  [-0.2130062   0.52526629 -1.33808816 ... -0.68198343 -0.89364651
#    1.2122095 ]
#  [-1.96523919 -0.02764552  0.08479538 ... -0.04541684  0.26622114
#   -0.39295903]
#  ...
#  [-0.07540705 -0.34134499  2.41812744 ... -0.02429674  0.87831431
#    1.51866858]
#  [-1.55472737  0.24754037 -1.77320031 ...  0.16542381  2.1871116
#    0.34967211]
#  [ 1.69410601 -0.57640836 -0.89925577 ... -0.49616576 -0.53862982
#   -0.41848694]]

# %%
print(Y_train)
# Out:
# 823    1
# 190    0
# 35     1
# 359    0
# 769    0
#       ..
# 689    0
# 640    1
# 191    1
# 951    0
# 64     0
# Name: TARGET CLASS, Length: 700, dtype: int64

# %%
print(X_test)
# Out:
# [[ 1.13074992 -0.78341156 -0.31114101 ... -1.20097398 -0.59004579
#   -0.67991639]
#  [-0.85814859  0.4343096  -1.01697965 ... -1.6679357  -0.21586799
#   -1.36368848]
#  [ 1.44375158  0.08981454 -0.59811828 ...  0.11159055 -0.31188857
#   -1.56738063]
#  ...
#  [-0.86945958  0.23986962  0.91513954 ... -0.44986772 -0.85889106
#    0.2254447 ]
#  [ 0.01153303  0.19132405 -1.43347252 ... -0.88855689  0.16230961
#   -0.00279348]
#  [-0.20435259 -0.27730551  1.3174944  ... -0.28210911 -1.23376212
#    0.51258591]]

# %%
print(Y_test)
# Out:
# 622    1
# 419    1
# 905    0
# 266    1
# 128    0
#       ..
# 120    1
# 395    0
# 557    1
# 3      0
# 570    1
# Name: TARGET CLASS, Length: 300, dtype: int64

# %%
clf =KNeighborsClassifier(n_neighbors=1)
clf.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
score = clf.score(X_train,Y_train)
score
# Out:
# 1.0

# %%
pred = clf.predict(X_test)

# %%
####SVM

# %%
from sklearn.svm import SVC

# %%
clf = SVC(kernel="linear",C=1)
clf.fit(X_train,Y_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
score = clf.score(X_train,Y_train)
print(clf.predict([[5.6,2.4]]))
# Out:
# ['virginica']

# %%
predict = clf.predict(X_test)
print('oreginal',Y_test)
print('Predict',predict)
# Out:
# oreginal ['virginica' 'versicolor' 'setosa' 'versicolor' 'virginica' 'setosa'
#  'versicolor' 'versicolor' 'setosa' 'versicolor' 'versicolor' 'versicolor'
#  'setosa' 'virginica' 'setosa' 'versicolor' 'virginica' 'virginica'
#  'setosa' 'setosa' 'versicolor' 'virginica' 'versicolor' 'virginica'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'virginica' 'virginica']
# Predict ['virginica' 'versicolor' 'setosa' 'versicolor' 'versicolor' 'setosa'
#  'versicolor' 'versicolor' 'setosa' 'versicolor' 'virginica' 'versicolor'
#  'setosa' 'virginica' 'setosa' 'virginica' 'virginica' 'virginica'
#  'setosa' 'setosa' 'versicolor' 'virginica' 'versicolor' 'virginica'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'virginica' 'virginica']

# %%
print(classification_report(Y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         7
#   versicolor       0.91      0.83      0.87        12
#    virginica       0.83      0.91      0.87        11
#
#     accuracy                           0.90        30
#    macro avg       0.91      0.91      0.91        30
# weighted avg       0.90      0.90      0.90        30
